# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyaverma/Crop-Disease-Prediction-Model-Analysis/blob/main/Tomato_GoogleNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import json
from zipfile import ZipFile
import shutil
from PIL import Image
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

from tensorflow import keras
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)  # suppress warnings
import random

from tensorflow.keras import Model, callbacks, layers, models, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import HTML

# %%
# Load Kaggle credentials and download dataset
kaggle_credentials = json.load(open("kaggle.json"))
os.environ['KAGGLE_USERNAME'] = kaggle_credentials["username"]
os.environ['KAGGLE_KEY'] = kaggle_credentials["key"]

# !kaggle datasets download -d kaustubhb999/tomatoleaf

# Unzip
with ZipFile("tomatoleaf.zip", 'r') as zip_ref:
    zip_ref.extractall()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kaustubhb999/tomatoleaf
# License(s): CC0-1.0
# Downloading tomatoleaf.zip to /content
#  86% 153M/179M [00:00<00:00, 1.59GB/s]
# 100% 179M/179M [00:00<00:00, 1.11GB/s]

# %%
# Paths from the dataset
train_path = "/content/tomato/train"
val_path = "/content/tomato/val"

# %% [markdown]
# **Create a unified folder**

# %%
# New unified folder
combined_path = "/content/tomato-leaf-disease"
os.makedirs(combined_path, exist_ok=True)

def combine_folders(source_dir, target_dir):
    for cls in os.listdir(source_dir):
        src_cls_path = os.path.join(source_dir, cls)
        dst_cls_path = os.path.join(target_dir, cls)
        os.makedirs(dst_cls_path, exist_ok=True)

        for file_name in os.listdir(src_cls_path):
            src_file = os.path.join(src_cls_path, file_name)
            dst_file = os.path.join(dst_cls_path, file_name)

            # Only copy if file doesn't already exist
            if not os.path.exists(dst_file):
                shutil.copy2(src_file, dst_file)

        print(f"Copied: {cls} from {source_dir} to {target_dir}")

# Combine all splits into one
combine_folders(train_path, combined_path)
combine_folders(val_path, combined_path)
# Out:
# Copied: Tomato___Leaf_Mold from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Tomato_Yellow_Leaf_Curl_Virus from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Early_blight from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Septoria_leaf_spot from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Bacterial_spot from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Spider_mites Two-spotted_spider_mite from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Late_blight from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Target_Spot from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Tomato_mosaic_virus from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___healthy from /content/tomato/train to /content/tomato-leaf-disease
# Copied: Tomato___Leaf_Mold from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Tomato_Yellow_Leaf_Curl_Virus from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Early_blight from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Septoria_leaf_spot from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Bacterial_spot from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Spider_mites Two-spotted_spider_mite from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Late_blight from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Target_Spot from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___Tomato_mosaic_virus from /content/tomato/val to /content/tomato-leaf-disease
# Copied: Tomato___healthy from /content/tomato/val to /content/tomato-leaf-disease

# %% [markdown]
# **Check for total image count**

# %%
def count_images_in_folders(folder_path):
    total_images = 0
    print(f"\nChecking folder: {folder_path}")
    for cls in sorted(os.listdir(folder_path)):
        cls_path = os.path.join(folder_path, cls)
        if os.path.isdir(cls_path):
            count = len(os.listdir(cls_path))
            total_images += count
            print(f"{cls}: {count} images")
    print(f"\nTotal images: {total_images}")

# Run this:
count_images_in_folders("/content/tomato-leaf-disease")
# Out:
# Checking folder: /content/tomato-leaf-disease
# Tomato___Bacterial_spot: 1100 images
# Tomato___Early_blight: 1100 images
# Tomato___Late_blight: 1100 images
# Tomato___Leaf_Mold: 1100 images
# Tomato___Septoria_leaf_spot: 1100 images
# Tomato___Spider_mites Two-spotted_spider_mite: 1100 images
# Tomato___Target_Spot: 1100 images
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: 1100 images
# Tomato___Tomato_mosaic_virus: 1100 images
# Tomato___healthy: 1100 images
#
# Total images: 11000

# %% [markdown]
# **Check for Corrupt or Unreadable Images**

# %%
def check_image_integrity(folder_path):
    broken = []
    for cls in os.listdir(folder_path):
        cls_path = os.path.join(folder_path, cls)
        for img_file in os.listdir(cls_path):
            try:
                img_path = os.path.join(cls_path, img_file)
                with Image.open(img_path) as img:
                    img.verify()
            except Exception as e:
                broken.append(img_path)
                print(f"Corrupt: {img_path} — {e}")
    if not broken:
        print("All images verified successfully.")
    else:
        print(f"Found {len(broken)} corrupt images.")

check_image_integrity("/content/tomato-leaf-disease")
# Out:
# All images verified successfully.

# %%
SEED = 123

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 8
CHANNELS = 3
EPOCHS = 30

# %% [markdown]
# **Import data into tensorflow dataset object**

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "tomato-leaf-disease",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 11000 files belonging to 10 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %% [markdown]
# **Visualize some of the images from our dataset**

# %%
plt.figure(figsize=(10, 10))

# Take one batch (usually of 32 images) from the dataset
for image_batch, labels_batch in dataset.take(1):

    # Loop through the first 12 images in the batch
    for i in range(BATCH_SIZE):

        # Create a subplot in a 3x4 grid (3 rows, 4 columns)
        ax = plt.subplot(3, 4, i + 1)

        # Convert the 12 images in the batch to a NumPy array and display it
        plt.imshow(image_batch[i].numpy().astype("uint8"))  # .astype("uint8") ensures correct color format

        # Convert the label tensor to a NumPy integer, use it to get the class name, and set as title
        plt.title(class_names[labels_batch[i]])

        # Turn off the axis ticks and grid for cleaner display
        plt.axis("off")

# %% [markdown]
# **Splitting the dataset**

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)
    if shuffle:
      ds = ds.shuffle(shuffle_size, seed=123)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 1100

# %%
len(val_ds)
# Out:
# 137

# %%
len(test_ds)
# Out:
# 138

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# **Preprocessing the Data**

# %% [markdown]
# **Resizing & Rescaling**

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %% [markdown]
# **Data Augmentation**

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# %%
# Train: resize → augment → prefetch
train_ds = train_ds.map(lambda x, y: (resize_and_rescale(x), (y, y, y)), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# Val/test: resize → prefetch (no augmentation)
val_ds = val_ds.map(lambda x, y: (resize_and_rescale(x), (y, y, y)), num_parallel_calls=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

test_ds = test_ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Loading the model**

# %%
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D,
    Flatten, Dropout, Dense, Input, BatchNormalization, Concatenate
)
from tensorflow.keras.models import Model

NUM_CLASSES = 10

def inceptionnet(x, filters, name=None):
    # 1x1 conv
    path1 = Conv2D(filters[0], (1,1), padding='same', activation='relu')(x)

    # 1x1 conv + 3x3 conv
    path2 = Conv2D(filters[1][0], (1,1), padding='same', activation='relu')(x)
    path2 = Conv2D(filters[1][1], (3,3), padding='same', activation='relu')(path2)

    # 1x1 conv + 5x5 conv
    path3 = Conv2D(filters[2][0], (1,1), padding='same', activation='relu')(x)
    path3 = Conv2D(filters[2][1], (5,5), padding='same', activation='relu')(path3)

    # 3x3 maxpool + 1x1 conv
    path4 = MaxPooling2D((3,3), strides=1, padding='same')(x)
    path4 = Conv2D(filters[3], (1,1), padding='same', activation='relu')(path4)

    return Concatenate(axis=-1, name=name)([path1, path2, path3, path4])

def helperfunction(x, name=None):
    x = AveragePooling2D((5,5), strides=3)(x)
    x = Conv2D(128, (1,1), activation='relu')(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.4)(x)
    x = Dense(NUM_CLASSES, activation='softmax', name=name)(x)
    return x

def googlenet(input_shape=(224,224,3)):
    inputs = Input(shape=input_shape)

    # Stem
    x = Conv2D(64, (7,7), strides=2, padding='same', activation='relu')(inputs)
    x = MaxPooling2D((3,3), strides=2, padding='same')(x)
    x = BatchNormalization()(x)

    x = Conv2D(64, (1,1), activation='relu')(x)
    x = Conv2D(192, (3,3), padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3,3), strides=2, padding='same')(x)

    # Inception blocks + auxiliary classifiers
    x = inceptionnet(x, [64, (96,128), (16,32), 32], name='inception_3a')
    x = inceptionnet(x, [128, (128,192), (32,96), 64], name='inception_3b')
    x = MaxPooling2D((3,3), strides=2, padding='same')(x)

    x = inceptionnet(x, [192, (96,208), (16,48), 64], name='inception_4a')
    aux1 = helperfunction(x, name='aux_output_1')

    x = inceptionnet(x, [160, (112,224), (24,64), 64], name='inception_4b')
    x = inceptionnet(x, [128, (128,256), (24,64), 64], name='inception_4c')
    x = inceptionnet(x, [112, (144,288), (32,64), 64], name='inception_4d')
    aux2 = helperfunction(x, name='aux_output_2')

    x = inceptionnet(x, [256, (160,320), (32,128), 128], name='inception_4e')
    x = MaxPooling2D((3,3), strides=2, padding='same')(x)

    x = inceptionnet(x, [256, (160,320), (32,128), 128], name='inception_5a')
    x = inceptionnet(x, [384, (192,384), (48,128), 128], name='inception_5b')

    # GlobalAveragePooling + final dense layer
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)
    final = Dense(NUM_CLASSES, activation='softmax', name='main_output')(x)

    # Build model
    model = Model(inputs=inputs, outputs=[final, aux1, aux2], name='GoogLeNet')
    return model

# %%
model = googlenet()
model.summary()
# Out:
# Model: "GoogLeNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      9,472 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 56, 56,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 56, 56,    │        256 │ max_pooling2d[0]… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 56, 56,    │      4,160 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 56, 56,    │    110,784 │ conv2d_1[0][0]    │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        768 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 28, 28,    │     18,528 │ max_pooling2d_1[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │      3,088 │ max_pooling2d_1[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ max_pooling2d_1[… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 28, 28,    │     12,352 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 28, 28,    │    110,720 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │     12,832 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │      6,176 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3a        │ (None, 28, 28,    │          0 │ conv2d_3[0][0],   │
# │ (Concatenate)       │ 256)              │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │     32,896 │ inception_3a[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 28, 28,    │      8,224 │ inception_3a[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 28, 28,    │          0 │ inception_3a[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │     32,896 │ inception_3a[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    221,376 │ conv2d_10[0][0]   │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 28, 28,    │     76,896 │ conv2d_12[0][0]   │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 28, 28,    │     16,448 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_3b        │ (None, 28, 28,    │          0 │ conv2d_9[0][0],   │
# │ (Concatenate)       │ 480)              │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 14, 14,    │          0 │ inception_3b[0][… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 14, 14,    │     46,176 │ max_pooling2d_4[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 14, 14,    │      7,696 │ max_pooling2d_4[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 14, 14,    │          0 │ max_pooling2d_4[… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 14, 14,    │     92,352 │ max_pooling2d_4[… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 14, 14,    │    179,920 │ conv2d_16[0][0]   │
# │                     │ 208)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 14, 14,    │     19,248 │ conv2d_18[0][0]   │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 14, 14,    │     30,784 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4a        │ (None, 14, 14,    │          0 │ conv2d_15[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_17[0][0],  │
# │                     │                   │            │ conv2d_19[0][0],  │
# │                     │                   │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 14, 14,    │     57,456 │ inception_4a[0][… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 14, 14,    │     12,312 │ inception_4a[0][… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 14, 14,    │          0 │ inception_4a[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 14, 14,    │     82,080 │ inception_4a[0][… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 14, 14,    │    226,016 │ conv2d_23[0][0]   │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 14, 14,    │     38,464 │ conv2d_25[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 14, 14,    │     32,832 │ max_pooling2d_6[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4b        │ (None, 14, 14,    │          0 │ conv2d_22[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_24[0][0],  │
# │                     │                   │            │ conv2d_26[0][0],  │
# │                     │                   │            │ conv2d_27[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 14, 14,    │     65,664 │ inception_4b[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 14, 14,    │     12,312 │ inception_4b[0][… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 14, 14,    │          0 │ inception_4b[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 14, 14,    │     65,664 │ inception_4b[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 14, 14,    │    295,168 │ conv2d_29[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 14, 14,    │     38,464 │ conv2d_31[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 14, 14,    │     32,832 │ max_pooling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4c        │ (None, 14, 14,    │          0 │ conv2d_28[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_30[0][0],  │
# │                     │                   │            │ conv2d_32[0][0],  │
# │                     │                   │            │ conv2d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 14, 14,    │     73,872 │ inception_4c[0][… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 14, 14,    │     16,416 │ inception_4c[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 14, 14,    │          0 │ inception_4c[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 14, 14,    │     57,456 │ inception_4c[0][… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 14, 14,    │    373,536 │ conv2d_35[0][0]   │
# │                     │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 14, 14,    │     51,264 │ conv2d_37[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 14, 14,    │     32,832 │ max_pooling2d_8[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4d        │ (None, 14, 14,    │          0 │ conv2d_34[0][0],  │
# │ (Concatenate)       │ 528)              │            │ conv2d_36[0][0],  │
# │                     │                   │            │ conv2d_38[0][0],  │
# │                     │                   │            │ conv2d_39[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 14, 14,    │     84,640 │ inception_4d[0][… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 14, 14,    │     16,928 │ inception_4d[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 14, 14,    │          0 │ inception_4d[0][… │
# │ (MaxPooling2D)      │ 528)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 14, 14,    │    135,424 │ inception_4d[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 14, 14,    │    461,120 │ conv2d_42[0][0]   │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 14, 14,    │    102,528 │ conv2d_44[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 14, 14,    │     67,712 │ max_pooling2d_9[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_4e        │ (None, 14, 14,    │          0 │ conv2d_41[0][0],  │
# │ (Concatenate)       │ 832)              │            │ conv2d_43[0][0],  │
# │                     │                   │            │ conv2d_45[0][0],  │
# │                     │                   │            │ conv2d_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 7, 7, 832) │          0 │ inception_4e[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 7, 7, 160) │    133,280 │ max_pooling2d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 7, 7, 32)  │     26,656 │ max_pooling2d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 7, 7, 832) │          0 │ max_pooling2d_10… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 7, 7, 256) │    213,248 │ max_pooling2d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 7, 7, 320) │    461,120 │ conv2d_48[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 7, 7, 128) │    102,528 │ conv2d_50[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 7, 7, 128) │    106,624 │ max_pooling2d_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5a        │ (None, 7, 7, 832) │          0 │ conv2d_47[0][0],  │
# │ (Concatenate)       │                   │            │ conv2d_49[0][0],  │
# │                     │                   │            │ conv2d_51[0][0],  │
# │                     │                   │            │ conv2d_52[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 7, 7, 192) │    159,936 │ inception_5a[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 7, 7, 48)  │     39,984 │ inception_5a[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 7, 7, 832) │          0 │ inception_5a[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 4, 4, 512) │          0 │ inception_4a[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 4, 4, 528) │          0 │ inception_4d[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 7, 7, 384) │    319,872 │ inception_5a[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 7, 7, 384) │    663,936 │ conv2d_54[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 7, 7, 128) │    153,728 │ conv2d_56[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 7, 7, 128) │    106,624 │ max_pooling2d_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 4, 4, 128) │     65,664 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 4, 4, 128) │     67,712 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inception_5b        │ (None, 7, 7,      │          0 │ conv2d_53[0][0],  │
# │ (Concatenate)       │ 1024)             │            │ conv2d_55[0][0],  │
# │                     │                   │            │ conv2d_57[0][0],  │
# │                     │                   │            │ conv2d_58[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ conv2d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 2048)      │          0 │ conv2d_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ inception_5b[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    524,544 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1024)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 10)        │     10,250 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_output_1        │ (None, 10)        │      2,570 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aux_output_2        │ (None, 10)        │      2,570 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,172,430 (27.36 MB)
#  Trainable params: 7,171,918 (27.36 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
learning_rate = 0.001
opti = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model.compile(
    loss=['sparse_categorical_crossentropy', 'sparse_categorical_crossentropy', 'sparse_categorical_crossentropy'],
    loss_weights=[1, 0.3, 0.3],
    optimizer=opti,
    metrics=[['accuracy'], ['accuracy'], ['accuracy']]
)

# %%
# Callbacks
from tensorflow.keras import callbacks


early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-6, verbose=1)
model_ckpt = callbacks.ModelCheckpoint(
    filepath="best_googlenet.h5",  # or best_alexnet.keras if using latest version
    save_best_only=True,
    monitor="val_loss"
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=[early_stop, reduce_lr, model_ckpt]
)
# Out:
# Epoch 1/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 162s 91ms/step - aux_output_1_accuracy: 0.2753 - aux_output_1_loss: 2.0316 - aux_output_2_accuracy: 0.1930 - aux_output_2_loss: 2.1452 - loss: 3.4310 - main_output_accuracy: 0.1745 - main_output_loss: 2.1780 - val_aux_output_1_accuracy: 0.4352 - val_aux_output_1_loss: 1.6410 - val_aux_output_2_accuracy: 0.4051 - val_aux_output_2_loss: 1.6310 - val_loss: 2.6369 - val_main_output_accuracy: 0.3869 - val_main_output_loss: 1.6553 - learning_rate: 0.0010
# Epoch 2/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 99s 79ms/step - aux_output_1_accuracy: 0.6479 - aux_output_1_loss: 0.9983 - aux_output_2_accuracy: 0.5815 - aux_output_2_loss: 1.1694 - loss: 1.8510 - main_output_accuracy: 0.5649 - main_output_loss: 1.2007 - val_aux_output_1_accuracy: 0.3796 - val_aux_output_1_loss: 1.9737 - val_aux_output_2_accuracy: 0.3403 - val_aux_output_2_loss: 2.1142 - val_loss: 3.2780 - val_main_output_accuracy: 0.3531 - val_main_output_loss: 2.0516 - learning_rate: 0.0010
# Epoch 3/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 96s 79ms/step - aux_output_1_accuracy: 0.7536 - aux_output_1_loss: 0.6993 - aux_output_2_accuracy: 0.7203 - aux_output_2_loss: 0.8276 - loss: 1.2892 - main_output_accuracy: 0.7019 - main_output_loss: 0.8311 - val_aux_output_1_accuracy: 0.7153 - val_aux_output_1_loss: 0.8053 - val_aux_output_2_accuracy: 0.7208 - val_aux_output_2_loss: 0.7454 - val_loss: 1.2271 - val_main_output_accuracy: 0.7153 - val_main_output_loss: 0.7619 - learning_rate: 0.0010
# Epoch 4/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 96s 79ms/step - aux_output_1_accuracy: 0.8225 - aux_output_1_loss: 0.5139 - aux_output_2_accuracy: 0.7951 - aux_output_2_loss: 0.5936 - loss: 0.9259 - main_output_accuracy: 0.7944 - main_output_loss: 0.5937 - val_aux_output_1_accuracy: 0.6469 - val_aux_output_1_loss: 1.4412 - val_aux_output_2_accuracy: 0.6168 - val_aux_output_2_loss: 1.4168 - val_loss: 2.3438 - val_main_output_accuracy: 0.6095 - val_main_output_loss: 1.4864 - learning_rate: 0.0010
# Epoch 5/20
# 1099/1100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - aux_output_1_accuracy: 0.8497 - aux_output_1_loss: 0.4452 - aux_output_2_accuracy: 0.8333 - aux_output_2_loss: 0.4852 - loss: 0.7595 - main_output_accuracy: 0.8307 - main_output_loss: 0.4804
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 97s 80ms/step - aux_output_1_accuracy: 0.8497 - aux_output_1_loss: 0.4451 - aux_output_2_accuracy: 0.8333 - aux_output_2_loss: 0.4852 - loss: 0.7595 - main_output_accuracy: 0.8307 - main_output_loss: 0.4804 - val_aux_output_1_accuracy: 0.7263 - val_aux_output_1_loss: 0.8652 - val_aux_output_2_accuracy: 0.7381 - val_aux_output_2_loss: 0.7971 - val_loss: 1.3237 - val_main_output_accuracy: 0.7235 - val_main_output_loss: 0.8250 - learning_rate: 0.0010
# Epoch 6/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 96s 79ms/step - aux_output_1_accuracy: 0.9052 - aux_output_1_loss: 0.2742 - aux_output_2_accuracy: 0.9014 - aux_output_2_loss: 0.2929 - loss: 0.4550 - main_output_accuracy: 0.8965 - main_output_loss: 0.2849 - val_aux_output_1_accuracy: 0.9544 - val_aux_output_1_loss: 0.1420 - val_aux_output_2_accuracy: 0.9462 - val_aux_output_2_loss: 0.1622 - val_loss: 0.2484 - val_main_output_accuracy: 0.9535 - val_main_output_loss: 0.1572 - learning_rate: 2.0000e-04
# Epoch 7/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 97s 80ms/step - aux_output_1_accuracy: 0.9240 - aux_output_1_loss: 0.2298 - aux_output_2_accuracy: 0.9214 - aux_output_2_loss: 0.2379 - loss: 0.3667 - main_output_accuracy: 0.9237 - main_output_loss: 0.2264 - val_aux_output_1_accuracy: 0.9544 - val_aux_output_1_loss: 0.1283 - val_aux_output_2_accuracy: 0.9571 - val_aux_output_2_loss: 0.1326 - val_loss: 0.2178 - val_main_output_accuracy: 0.9516 - val_main_output_loss: 0.1395 - learning_rate: 2.0000e-04
# Epoch 8/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 100s 82ms/step - aux_output_1_accuracy: 0.9333 - aux_output_1_loss: 0.1928 - aux_output_2_accuracy: 0.9280 - aux_output_2_loss: 0.2099 - loss: 0.3121 - main_output_accuracy: 0.9309 - main_output_loss: 0.1913 - val_aux_output_1_accuracy: 0.9717 - val_aux_output_1_loss: 0.0843 - val_aux_output_2_accuracy: 0.9662 - val_aux_output_2_loss: 0.0996 - val_loss: 0.1568 - val_main_output_accuracy: 0.9644 - val_main_output_loss: 0.1016 - learning_rate: 2.0000e-04
# Epoch 9/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 108s 86ms/step - aux_output_1_accuracy: 0.9393 - aux_output_1_loss: 0.1738 - aux_output_2_accuracy: 0.9406 - aux_output_2_loss: 0.1760 - loss: 0.2688 - main_output_accuracy: 0.9408 - main_output_loss: 0.1639 - val_aux_output_1_accuracy: 0.9599 - val_aux_output_1_loss: 0.1211 - val_aux_output_2_accuracy: 0.9507 - val_aux_output_2_loss: 0.1360 - val_loss: 0.2052 - val_main_output_accuracy: 0.9571 - val_main_output_loss: 0.1281 - learning_rate: 2.0000e-04
# Epoch 10/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - aux_output_1_accuracy: 0.9451 - aux_output_1_loss: 0.1605 - aux_output_2_accuracy: 0.9407 - aux_output_2_loss: 0.1714 - loss: 0.2555 - main_output_accuracy: 0.9456 - main_output_loss: 0.1559
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 107s 85ms/step - aux_output_1_accuracy: 0.9451 - aux_output_1_loss: 0.1605 - aux_output_2_accuracy: 0.9407 - aux_output_2_loss: 0.1714 - loss: 0.2555 - main_output_accuracy: 0.9456 - main_output_loss: 0.1559 - val_aux_output_1_accuracy: 0.9644 - val_aux_output_1_loss: 0.1099 - val_aux_output_2_accuracy: 0.9672 - val_aux_output_2_loss: 0.1240 - val_loss: 0.1909 - val_main_output_accuracy: 0.9662 - val_main_output_loss: 0.1207 - learning_rate: 2.0000e-04
# Epoch 11/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 134s 82ms/step - aux_output_1_accuracy: 0.9540 - aux_output_1_loss: 0.1378 - aux_output_2_accuracy: 0.9534 - aux_output_2_loss: 0.1413 - loss: 0.2052 - main_output_accuracy: 0.9564 - main_output_loss: 0.1215 - val_aux_output_1_accuracy: 0.9717 - val_aux_output_1_loss: 0.0772 - val_aux_output_2_accuracy: 0.9708 - val_aux_output_2_loss: 0.0820 - val_loss: 0.1269 - val_main_output_accuracy: 0.9717 - val_main_output_loss: 0.0792 - learning_rate: 4.0000e-05
# Epoch 12/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 100s 82ms/step - aux_output_1_accuracy: 0.9578 - aux_output_1_loss: 0.1281 - aux_output_2_accuracy: 0.9585 - aux_output_2_loss: 0.1284 - loss: 0.1926 - main_output_accuracy: 0.9618 - main_output_loss: 0.1157 - val_aux_output_1_accuracy: 0.9754 - val_aux_output_1_loss: 0.0726 - val_aux_output_2_accuracy: 0.9754 - val_aux_output_2_loss: 0.0681 - val_loss: 0.1039 - val_main_output_accuracy: 0.9772 - val_main_output_loss: 0.0617 - learning_rate: 4.0000e-05
# Epoch 13/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 99s 82ms/step - aux_output_1_accuracy: 0.9600 - aux_output_1_loss: 0.1207 - aux_output_2_accuracy: 0.9594 - aux_output_2_loss: 0.1169 - loss: 0.1737 - main_output_accuracy: 0.9670 - main_output_loss: 0.1024 - val_aux_output_1_accuracy: 0.9790 - val_aux_output_1_loss: 0.0596 - val_aux_output_2_accuracy: 0.9772 - val_aux_output_2_loss: 0.0554 - val_loss: 0.0882 - val_main_output_accuracy: 0.9827 - val_main_output_loss: 0.0537 - learning_rate: 4.0000e-05
# Epoch 14/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 98s 81ms/step - aux_output_1_accuracy: 0.9626 - aux_output_1_loss: 0.1117 - aux_output_2_accuracy: 0.9658 - aux_output_2_loss: 0.1096 - loss: 0.1647 - main_output_accuracy: 0.9659 - main_output_loss: 0.0983 - val_aux_output_1_accuracy: 0.9845 - val_aux_output_1_loss: 0.0612 - val_aux_output_2_accuracy: 0.9790 - val_aux_output_2_loss: 0.0644 - val_loss: 0.1064 - val_main_output_accuracy: 0.9754 - val_main_output_loss: 0.0687 - learning_rate: 4.0000e-05
# Epoch 15/20
# 1099/1100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - aux_output_1_accuracy: 0.9670 - aux_output_1_loss: 0.1073 - aux_output_2_accuracy: 0.9664 - aux_output_2_loss: 0.0997 - loss: 0.1506 - main_output_accuracy: 0.9716 - main_output_loss: 0.0885
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 104s 86ms/step - aux_output_1_accuracy: 0.9670 - aux_output_1_loss: 0.1073 - aux_output_2_accuracy: 0.9664 - aux_output_2_loss: 0.0997 - loss: 0.1506 - main_output_accuracy: 0.9716 - main_output_loss: 0.0885 - val_aux_output_1_accuracy: 0.9763 - val_aux_output_1_loss: 0.0604 - val_aux_output_2_accuracy: 0.9763 - val_aux_output_2_loss: 0.0642 - val_loss: 0.1000 - val_main_output_accuracy: 0.9754 - val_main_output_loss: 0.0626 - learning_rate: 4.0000e-05
# Epoch 16/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 110s 87ms/step - aux_output_1_accuracy: 0.9598 - aux_output_1_loss: 0.1187 - aux_output_2_accuracy: 0.9602 - aux_output_2_loss: 0.1200 - loss: 0.1767 - main_output_accuracy: 0.9638 - main_output_loss: 0.1051 - val_aux_output_1_accuracy: 0.9891 - val_aux_output_1_loss: 0.0351 - val_aux_output_2_accuracy: 0.9891 - val_aux_output_2_loss: 0.0336 - val_loss: 0.0497 - val_main_output_accuracy: 0.9936 - val_main_output_loss: 0.0291 - learning_rate: 8.0000e-06
# Epoch 17/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 145s 88ms/step - aux_output_1_accuracy: 0.9634 - aux_output_1_loss: 0.1049 - aux_output_2_accuracy: 0.9670 - aux_output_2_loss: 0.0968 - loss: 0.1490 - main_output_accuracy: 0.9698 - main_output_loss: 0.0885 - val_aux_output_1_accuracy: 0.9763 - val_aux_output_1_loss: 0.0663 - val_aux_output_2_accuracy: 0.9799 - val_aux_output_2_loss: 0.0692 - val_loss: 0.1122 - val_main_output_accuracy: 0.9790 - val_main_output_loss: 0.0716 - learning_rate: 8.0000e-06
# Epoch 18/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - aux_output_1_accuracy: 0.9653 - aux_output_1_loss: 0.1026 - aux_output_2_accuracy: 0.9701 - aux_output_2_loss: 0.1020 - loss: 0.1497 - main_output_accuracy: 0.9700 - main_output_loss: 0.0883
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 114s 88ms/step - aux_output_1_accuracy: 0.9653 - aux_output_1_loss: 0.1026 - aux_output_2_accuracy: 0.9701 - aux_output_2_loss: 0.1020 - loss: 0.1497 - main_output_accuracy: 0.9700 - main_output_loss: 0.0883 - val_aux_output_1_accuracy: 0.9854 - val_aux_output_1_loss: 0.0445 - val_aux_output_2_accuracy: 0.9827 - val_aux_output_2_loss: 0.0423 - val_loss: 0.0684 - val_main_output_accuracy: 0.9881 - val_main_output_loss: 0.0423 - learning_rate: 8.0000e-06
# Epoch 19/20
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 118s 93ms/step - aux_output_1_accuracy: 0.9633 - aux_output_1_loss: 0.1004 - aux_output_2_accuracy: 0.9668 - aux_output_2_loss: 0.1016 - loss: 0.1482 - main_output_accuracy: 0.9692 - main_output_loss: 0.0876 - val_aux_output_1_accuracy: 0.9863 - val_aux_output_1_loss: 0.0458 - val_aux_output_2_accuracy: 0.9827 - val_aux_output_2_loss: 0.0497 - val_loss: 0.0786 - val_main_output_accuracy: 0.9836 - val_main_output_loss: 0.0499 - learning_rate: 1.6000e-06
# Epoch 20/20
# 1099/1100 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - aux_output_1_accuracy: 0.9601 - aux_output_1_loss: 0.1107 - aux_output_2_accuracy: 0.9671 - aux_output_2_loss: 0.1045 - loss: 0.1598 - main_output_accuracy: 0.9681 - main_output_loss: 0.0952
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 123s 95ms/step - aux_output_1_accuracy: 0.9601 - aux_output_1_loss: 0.1106 - aux_output_2_accuracy: 0.9671 - aux_output_2_loss: 0.1045 - loss: 0.1598 - main_output_accuracy: 0.9681 - main_output_loss: 0.0952 - val_aux_output_1_accuracy: 0.9818 - val_aux_output_1_loss: 0.0615 - val_aux_output_2_accuracy: 0.9827 - val_aux_output_2_loss: 0.0590 - val_loss: 0.0983 - val_main_output_accuracy: 0.9790 - val_main_output_loss: 0.0621 - learning_rate: 1.6000e-06

# %%
acc = history.history['main_output_accuracy']
val_acc = history.history['val_main_output_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize = (12,5))

plt.subplot(1,2,1)
plt.plot(history.history['main_output_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_main_output_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Main Output Accuracy')

plt.subplot(1,2,2)
plt.plot(history.history['main_output_loss'], label='Training Loss')
plt.plot(history.history['val_main_output_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Main Output Loss')

plt.show()

# %%
for image_batch, label_batch in test_ds.take(1):
    first_image = (image_batch[0].numpy() * 255).astype('uint8')
    first_label = label_batch[0].numpy()

    print("first image to print")
    plt.imshow(first_image)
    plt.show()

    print("first image actual label:", class_names[first_label])

    # predict on batch: returns list [main_output, aux_output_1, aux_output_2]
    batch_prediction = model.predict(image_batch)

    # get main output predictions
    main_predictions = batch_prediction[0]

    # get the prediction vector for the first image
    first_pred = main_predictions[0]

    # get predicted class index
    predicted_class_idx = np.argmax(first_pred)

    print("predicted label:", class_names[predicted_class_idx])
# Out:
# first image to print
# first image actual label: Tomato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# predicted label: Tomato___Late_blight

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img, )
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))

for images, labels in test_ds.take(1):
    for i in range(BATCH_SIZE):
        ax = plt.subplot(3, 3, i + 1)

        # rescale for display
        display_image = (images[i].numpy() * 255).astype("uint8")
        plt.imshow(display_image)

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class}\nPredicted: {predicted_class}\nConfidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %% [markdown]
# **Model Predictions**

# %%
y_true = []
y_pred = []
y_prob = []

for images, labels in test_ds:
    preds_list = model.predict(images)
    preds = preds_list[0]  # main_output predictions: shape (batch_size, num_classes)

    preds_classes = np.argmax(preds, axis=1)  # shape (batch_size,)
    true_classes = labels.numpy()

    y_true.extend(true_classes)
    y_pred.extend(preds_classes)
    y_prob.extend(preds)  # add the raw probabilities

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_prob = np.array(y_prob)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# %% [markdown]
# **Accuracy**

# %%
acc = accuracy_score(y_true, y_pred)
print(f"Accuracy: {acc * 100:.2f}%")
# Out:
# Accuracy: 99.28%

# %% [markdown]
# **Precision**

# %%
precision = precision_score(y_true, y_pred, average='weighted')  # or 'macro', 'micro'
print(f"Precision: {precision * 100:.2f}%")
# Out:
# Precision: 99.28%

# %% [markdown]
# **Recall**

# %%
recall = recall_score(y_true, y_pred, average='weighted')
print(f"Recall: {recall * 100:.2f}%")
# Out:
# Recall: 99.28%

# %% [markdown]
# **F1 Score**

# %%
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"f1: {f1 * 100:.2f}%")
# Out:
# f1: 99.27%

# %% [markdown]
# **Confusion Matrix**

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# **Classification Report**

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
)

print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#                                                precision    recall  f1-score   support
#
#                       Tomato___Bacterial_spot     1.0000    0.9825    0.9912       114
#                         Tomato___Early_blight     1.0000    1.0000    1.0000       128
#                          Tomato___Late_blight     0.9906    1.0000    0.9953       105
#                            Tomato___Leaf_Mold     1.0000    1.0000    1.0000       115
#                   Tomato___Septoria_leaf_spot     1.0000    1.0000    1.0000       105
# Tomato___Spider_mites Two-spotted_spider_mite     0.9808    0.9623    0.9714       106
#                          Tomato___Target_Spot     0.9831    0.9915    0.9872       117
#        Tomato___Tomato_Yellow_Leaf_Curl_Virus     0.9820    0.9909    0.9864       110
#                  Tomato___Tomato_mosaic_virus     0.9895    1.0000    0.9947        94
#                              Tomato___healthy     1.0000    1.0000    1.0000       110
#
#                                      accuracy                         0.9928      1104
#                                     macro avg     0.9926    0.9927    0.9926      1104
#                                  weighted avg     0.9928    0.9928    0.9927      1104

# %% [markdown]
# **AUROC**

# %%
from sklearn.metrics import roc_auc_score

try:
    auc_score = roc_auc_score(y_true, y_prob, multi_class='ovr', average='macro') * 100
    print(f"Macro-Averaged ROC-AUC Score: {auc_score:.2f}%")
except Exception as e:
    print("ROC AUC not available:", e)
# Out:
# Macro-Averaged ROC-AUC Score: 99.99%

# %%
model.save('tomato-leaf-disease_GoogleNet_model.keras')

print("Model saved successfully!")
# Out:
# Model saved successfully!
